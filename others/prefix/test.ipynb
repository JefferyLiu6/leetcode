# %%
nums = [1, 2, 3, 4, 5]
n = len(nums)
prefixSum = [0] * (n + 1)

# %%
prefixSum
# Out:
# [0, 0, 0, 0, 0, 0]

# %%
for i in range(n):
    prefixSum[i+1] = prefixSum[i] + nums[i]

# %%
i=3

# %%
leftSum = prefixSum[i]
rightSum = prefixSum[n] - prefixSum[i+1]

# %%
prefixSum
# Out:
# [0, 1, 3, 6, 10, 15]

# %%
leftSum
# Out:
# 6

# %%
rightSum
# Out:
# 5

# %%
prefixSum[n]
# Out:
# 15
